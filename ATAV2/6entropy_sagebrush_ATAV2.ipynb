# %% [markdown]
# # Does everything to run entropy and creates slurm files to submit for all diploid likelihoods from bcftools for both *tridentata* and *vayesana*
#
# Goal is 4 chains k=2-7.

# %%
# !source activate py36
# Out:
# /usr/bin/sh: line 0: source: activate: file not found

# %%
import sys

#sys.path.append('/home/faske/g/anaconda3/envs/py34/lib/python3.4/site-packages')
sys.path.append('/data/gpfs/assoc/parchmanlab/tfaske/anaconda3/envs/py36/lib/python3.6/site-packages')
sys.path.append("/data/gpfs/assoc/parchmanlab/tfaske/ipynb/include_utils")

import ipyparallel as ipp
import os, time
import include_utils as u
import pandas as pd
import numpy as np
import scipy as sp
import random
import numbers
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.cm as cm
import matplotlib.colors as mcolors
#import vcf
from sklearn import preprocessing
from subprocess import Popen, PIPE, call, check_output
import seaborn as sns
from IPython.display import FileLink
import urllib.request as urllib2
import dill
import traceback
from pandas import Series, DataFrame
import gzip
import warnings
warnings.filterwarnings('ignore',category=pd.io.pytables.PerformanceWarning)
# %config InlineBackend.figure_format = 'retina'
from Bio import SeqIO
#import pysam
from collections import OrderedDict, namedtuple, Counter
import operator
import multiprocessing as mp
import shutil
import tempfile
#from ipyparallel import Client
import scandir
import glob
from Bio.SeqIO.QualityIO import FastqGeneralIterator
import pickle
import re
from itertools import chain
#import Levenshtein as lv

# %%
root = '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2'

# %%
cd $root
# Out:
# /data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2

# %% [markdown]
# ### Create mgpl & pntest files with associated dir

# %%
ent_dir =os.path.join(root,'entropy')
assert ent_dir

# %%
cd $ent_dir
# Out:
# /data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy

# %%
# !gunzip 'final_snps.recode.vcf.gz'

# %%
vcf = 'final_snps.recode.vcf'
vcf
# Out:
# 'final_snps.recode.vcf'

# %%
perl_mpgl = '/data/gpfs/home/tfaske/g/src/perl_scripts/vcf2mpgl_milkweed.pl'
perl_mean = '/data/gpfs/home/tfaske/g/src/perl_scripts/gl2genest_milkweed.pl'

# %%
# !perl $perl_mpgl $vcf
# Out:
# Number of loci: 13003; number of individuals 397

# %%
mpgl = 'final_snps.recode.mpgl'

# %%
# !perl $perl_mean $mpgl mean

# %% [markdown]
# ### Create ldak files in R

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# require(readr)
# require(MASS)
# require(LEA)
# require(ggplot2)
# require(ggsci)
# require(patchwork)
#
# source('/data/gpfs/home/tfaske/g/src/R/Imports.R')
#
# setwd('/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy')
# Out:
# R[write to console]: Loading required package: LEA

# %%
# %%R
# #create Pop_ID file
#
# indv<-read.table("../filtering/final_snps.recode.vcf.012.indv",sep="\t")
#
# Sp <- rep(NA,times=nrow(indv))
# Ploidy <- rep(NA,times=nrow(indv))
# Pop <- rep(NA,times=nrow(indv))
# ID <- rep(NA,times=nrow(indv))
# All <- rep(NA,times=nrow(indv))
# for (i in 1:nrow(indv)){
#   SpP <- unlist(strsplit(as.character(indv$V1[i]),"_"))[1]
#   Sp[i] <- gsub('\\d','',SpP,perl=TRUE)
#   Ploidy[i] <-  gsub('(\\D)','',SpP,perl=TRUE)
#   Pop[i] <- unlist(strsplit(as.character(indv$V1[i]),"_"))[2]
#   ID[i] <- unlist(strsplit(as.character(indv$V1[i]),"_"))[3]
#   All[i] <- as.character(indv$V1[i])
# }
# Pop_ID <- data.frame(Sp=Sp,Ploidy=Ploidy,Pop=Pop,ID=ID,All=All,
#                      SpPloidy=paste0(Sp,Ploidy))
#
# print(head(Pop_ID))
#
# write.csv(Pop_ID,"Pop_ID.csv",row.names = FALSE)
# Out:
#   Sp Ploidy Pop ID       All SpPloidy
# 1 AT      2  BB 10 AT2_BB_10      AT2
# 2 AT      2  BB 11 AT2_BB_11      AT2
# 3 AT      2  BB 12 AT2_BB_12      AT2
# 4 AT      2  BB 13 AT2_BB_13      AT2
# 5 AT      2  BB 14 AT2_BB_14      AT2
# 6 AT      2  BB 15 AT2_BB_15      AT2

# %%
# %%R
# g <- read.table("pntest_mean_final_snps.recode.txt", header=F)
# dim(g)
# Out:
# [1] 13003   397

# %%
# %%R
# Pop_ID <- read.csv("Pop_ID.csv")
# pca_df <- PCA_entropy(t(g))
# Out:
#     PC1     PC2     PC3     PC4     PC5
# 0.12569 0.02958 0.01392 0.01094 0.00943

# %%
# %%R
# pca_df <- cbind(pca_df[,1:10],Pop_ID)
#
# col2 <- c("#899DA4","#C93312")
# ggplot(data = pca_df, aes(x=PC1,y=PC2,fill=Sp,shape=as.character(Ploidy))) +
#   geom_point(colour='black',size = 4)+ #ggtitle("PCA ARTR all") +
#   xlab(paste("PC",1," (",0.12569*100,"%)",sep="")) +
#   ylab(paste("PC",2," (",0.02958*100,"%)",sep=""))  +
#   scale_fill_manual(name='Subspecies:',values = col2) +
#   scale_shape_manual(name='Ploidy:',values = c(21,24)) +
#   guides(fill = guide_legend(override.aes=list(pch=21))) +
#   theme_bw() +
#   theme(#legend.position = 'none',
#     axis.text = element_text(size=11),
#     axis.title = element_text(size = 13, colour="black",face = "bold",vjust = 1),
#     panel.border = element_rect(size = 1.5, colour = "black"),
#     panel.grid.major = element_blank(),
#     panel.grid.minor = element_blank())

# %%
# %%R
# #######################################################################################
#                                     #### LDA ####
# #######################################################################################
#
# k2<-kmeans(pca_df[,1:5],2,iter.max=10,nstart=10,algorithm="Hartigan-Wong")
# k3<-kmeans(pca_df[,1:5],3,iter.max=10,nstart=10,algorithm="Hartigan-Wong")
# k4<-kmeans(pca_df[,1:5],4,iter.max=10,nstart=10,algorithm="Hartigan-Wong")
# k5<-kmeans(pca_df[,1:5],5,iter.max=10,nstart=10,algorithm="Hartigan-Wong")
# k6<-kmeans(pca_df[,1:5],6,iter.max=10,nstart=10,algorithm="Hartigan-Wong")
# k7<-kmeans(pca_df[,1:5],7,iter.max=10,nstart=10,algorithm="Hartigan-Wong")
# k8<-kmeans(pca_df[,1:5],8,iter.max=10,nstart=10,algorithm="Hartigan-Wong")
# k9<-kmeans(pca_df[,1:5],9,iter.max=10,nstart=10,algorithm="Hartigan-Wong")
# k10<-kmeans(pca_df[,1:5],10,iter.max=10,nstart=10,algorithm="Hartigan-Wong")
# k11<-kmeans(pca_df[,1:5],11,iter.max=10,nstart=10,algorithm="Hartigan-Wong")
#
# ldak2<-lda(x=pca_df[,1:5],grouping=k2$cluster,CV=TRUE)
# ldak3<-lda(x=pca_df[,1:5],grouping=k3$cluster,CV=TRUE)
# ldak4<-lda(x=pca_df[,1:5],grouping=k4$cluster,CV=TRUE)
# ldak5<-lda(x=pca_df[,1:5],grouping=k5$cluster,CV=TRUE)
# ldak6<-lda(x=pca_df[,1:5],grouping=k6$cluster,CV=TRUE)
# ldak7<-lda(x=pca_df[,1:5],grouping=k7$cluster,CV=TRUE)
# ldak8<-lda(x=pca_df[,1:5],grouping=k8$cluster,CV=TRUE)
# ldak9<-lda(x=pca_df[,1:5],grouping=k9$cluster,CV=TRUE)
# ldak10<-lda(x=pca_df[,1:5],grouping=k10$cluster,CV=TRUE)
# ldak11<-lda(x=pca_df[,1:5],grouping=k11$cluster,CV=TRUE)
#
# write.table(round(ldak2$posterior,5),file="ldak2.txt",quote=F,row.names=F,col.names=F)
# write.table(round(ldak3$posterior,5),file="ldak3.txt",quote=F,row.names=F,col.names=F)
# write.table(round(ldak4$posterior,5),file="ldak4.txt",quote=F,row.names=F,col.names=F)
# write.table(round(ldak5$posterior,5),file="ldak5.txt",quote=F,row.names=F,col.names=F)
# write.table(round(ldak6$posterior,5),file="ldak6.txt",quote=F,row.names=F,col.names=F)
# write.table(round(ldak7$posterior,5),file="ldak7.txt",quote=F,row.names=F,col.names=F)
# write.table(round(ldak8$posterior,5),file="ldak8.txt",quote=F,row.names=F,col.names=F)
# write.table(round(ldak9$posterior,5),file="ldak9.txt",quote=F,row.names=F,col.names=F)
# write.table(round(ldak10$posterior,5),file="ldak10.txt",quote=F,row.names=F,col.names=F)
# write.table(round(ldak11$posterior,5),file="ldak11.txt",quote=F,row.names=F,col.names=F)

# %%
# %%R
# ######### create entropy header ####
#
# Pop_ID_list <- Pop_ID$All
#
# Header <- data.frame(dims = NA,Pop_ID_list)
#
# dim(g)
#
# df <- t(Header)
# dims <- paste(dim(g)[2],dim(g)[1],sep = " ")
#
# df[1,1] <- dims
#
# write.table(df,'entropy_header.txt',sep = " ",na ="",
#             quote = FALSE,row.names = FALSE,col.names = FALSE)

# %%
# !head entropy_header.txt
# Out:
# 397 13003
# AT2_BB_10 AT2_BB_11 AT2_BB_12 AT2_BB_13 AT2_BB_14 AT2_BB_15 AT2_BB_16 AT2_BB_17 AT2_BB_1 AT2_BB_2 AT2_BB_3 AT2_BB_4 AT2_BB_5 AT2_BB_6 AT2_BB_7 AT2_BB_8 AT2_BB_9 AT2_BC_17 AT2_BC_18 AT2_BC_19 AT2_BC_20 AT2_BC_21 AT2_BC_22 AT2_BC_23 AT2_BT_1 AT2_BT_2 AT2_BT_3 AT2_BT_4 AT2_BT_57 AT2_BT_58 AT2_BT_59 AT2_BT_5 AT2_BT_60 AT2_BT_61 AT2_BT_62 AT2_BT_63 AT2_BT_64 AT2_BT_6 AT2_BT_7 AT2_BW_1 AT2_BW_65 AT2_BW_66 AT2_BW_67 AT2_BW_68 AT2_BW_69 AT2_BW_70 AT2_BW_71 AT2_BW_72 AT2_CB_24 AT2_CB_25 AT2_CB_26 AT2_CB_27 AT2_CB_28 AT2_CB_29 AT2_CB_30 AT2_CB_31 AT2_CB_32 AT2_DK_16 AT2_DK_17 AT2_DK_18 AT2_DK_19 AT2_DK_20 AT2_DK_21 AT2_DK_22 AT2_DK_23 AT2_DK_24 AT2_DK_25 AT2_DK_26 AT2_DK_27 AT2_DK_28 AT2_DK_29 AT2_DK_30 AT2_DT_10 AT2_DT_11 AT2_DT_12 AT2_DT_13 AT2_DT_14 AT2_DT_15 AT2_DT_1 AT2_DT_2 AT2_DT_3 AT2_DT_4 AT2_DT_5 AT2_DT_6 AT2_DT_7 AT2_DT_8 AT2_DT_9 AT2_EC_45 AT2_EC_46 AT2_EC_47 AT2_EC_48 AT2_EC_49 AT2_EC_50 AT2_EC_51 AT2_EC_52 AT2_EC_53 AT2_EW_31 AT2_EW_32 AT2_EW_33 AT2_EW_34 AT2_EW_35 AT2_EW_36 AT2_EW_37 AT2_EW_39 AT2_EW_40 AT2_HC_1 AT2_HC_2 AT2_HC_3 AT2_HC_4 AT2_HC_5 AT2_HC_6 AT2_HC_7 AT2_HC_8 AT2_JV_1 AT2_JV_2 AT2_JV_37 AT2_JV_38 AT2_JV_39 AT2_JV_3 AT2_JV_40 AT2_JV_41 AT2_JV_42 AT2_JV_43 AT2_JV_44 AT2_JV_4 AT2_JV_5 AT2_JV_6 AT2_JV_7 AT2_KN_80 AT2_KN_81 AT2_KN_82 AT2_KN_83 AT2_KN_84 AT2_KN_85 AT2_KN_86 AT2_KN_87 AT2_KN_88 AT2_KN_89 AT2_KN_90 AT2_KN_91 AT2_KN_92 AT2_KN_93 AT2_KN_94 AT2_LB_1 AT2_LB_2 AT2_LB_3 AT2_LB_4 AT2_LB_5 AT2_LB_6 AT2_LB_7 AT2_LB_8 AT2_LB_9 AT2_LN_1 AT2_LN_2 AT2_LN_3 AT2_LN_4 AT2_LN_5 AT2_LN_6 AT2_LN_96 AT2_LN_98 AT2_OC_15 AT2_OC_16 AT2_OC_2 AT2_OC_3 AT2_OC_4 AT2_OC_5 AT2_OC_6 AT2_OC_7 AT2_OC_8 AT2_OT_11 AT2_OT_12 AT2_OT_13 AT2_OT_14 AT2_OT_5 AT2_OT_6 AT2_OT_7 AT2_OT_8 AT2_OT_9 AT2_RB_100 AT2_RB_101 AT2_RB_102 AT2_RB_103 AT2_RB_104 AT2_RB_105 AT2_RB_106 AT2_RB_107 AT2_RB_108 AT2_RB_1 AT2_RB_3 AT2_RB_4 AT2_RB_5 AT2_RB_6 AT2_RB_7 AT2_RB_99 AT2_RK_1 AT2_RK_2 AT2_RK_3 AT2_RK_4 AT2_RK_5 AT2_RK_6 AT2_RK_7 AT2_SS_10 AT2_SS_1 AT2_SS_2 AT2_SS_3 AT2_SS_4 AT2_SS_5 AT2_SS_6 AT2_SS_7 AT2_VM_10 AT2_VM_1 AT2_VM_2 AT2_VM_3 AT2_VM_4 AT2_VM_5 AT2_VM_6 AT2_VM_7 AT2_VM_8 AT2_VM_9 AT2_YB_1 AT2_YB_2 AT2_YB_73 AT2_YB_74 AT2_YB_75 AT2_YB_76 AT2_YB_77 AT2_YB_78 AT2_YB_79 AV2_AN_1 AV2_AN_2 AV2_AN_3 AV2_AN_4 AV2_AN_5 AV2_AN_6 AV2_AN_7 AV2_AN_8 AV2_AS_61 AV2_AS_62 AV2_AS_63 AV2_AS_64 AV2_AS_65 AV2_AS_66 AV2_AS_67 AV2_AS_68 AV2_AS_69 AV2_AS_70 AV2_AS_71 AV2_AS_72 AV2_AS_73 AV2_AS_74 AV2_AS_75 AV2_BM_76 AV2_BM_77 AV2_BM_78 AV2_BM_79 AV2_BM_80 AV2_BM_81 AV2_BM_82 AV2_BM_83 AV2_BM_84 AV2_BM_85 AV2_BM_86 AV2_BM_87 AV2_BM_88 AV2_BM_89 AV2_BM_90 AV2_CC_134 AV2_CC_135 AV2_CC_136 AV2_CC_137 AV2_CC_138 AV2_CC_139 AV2_CC_140 AV2_CC_141 AV2_CC_1 AV2_CC_2 AV2_CC_3 AV2_CC_4 AV2_CC_5 AV2_CC_6 AV2_CC_7 AV2_CV_157 AV2_CV_158 AV2_CV_159 AV2_CV_160 AV2_CV_161 AV2_CV_162 AV2_CV_163 AV2_CV_164 AV2_CV_165 AV2_CV_166 AV2_CV_1 AV2_CV_2 AV2_CV_3 AV2_CV_4 AV2_CV_5 AV2_CV_6 AV2_CV_7 AV2_FP_1 AV2_FP_2 AV2_FP_3 AV2_FP_4 AV2_FP_5 AV2_FP_6 AV2_FP_7 AV2_GC_1 AV2_GC_2 AV2_GC_3 AV2_GC_4 AV2_GC_5 AV2_GC_6 AV2_GC_7 AV2_GC_8 AV2_GC_9 AV2_LV_100 AV2_LV_101 AV2_LV_102 AV2_LV_103 AV2_LV_104 AV2_LV_105 AV2_LV_91 AV2_LV_92 AV2_LV_93 AV2_LV_94 AV2_LV_95 AV2_LV_96 AV2_LV_97 AV2_LV_98 AV2_LV_99 AV2_NV_2 AV2_NV_3 AV2_NV_4 AV2_NV_5 AV2_NV_6 AV2_NV_7 AV2_NV_8 AV2_NV_9 AV2_PL_10 AV2_PL_1 AV2_PL_2 AV2_PL_3 AV2_PL_4 AV2_PL_5 AV2_PL_6 AV2_PL_7 AV2_PL_8 AV2_PL_9 AV2_PR_10 AV2_PR_2 AV2_PR_3 AV2_PR_4 AV2_PR_5 AV2_PR_6 AV2_PR_7 AV2_PR_8 AV2_PR_9 AV2_PT_10 AV2_PT_1 AV2_PT_2 AV2_PT_3 AV2_PT_4 AV2_PT_5 AV2_PT_6 AV2_PT_7 AV2_PT_8 AV2_PT_9 AV2_SN_125 AV2_SN_126 AV2_SN_127 AV2_SN_129 AV2_SN_130 AV2_SN_131 AV2_SN_132 AV2_SN_133 AV2_SN_1 AV2_SN_2 AV2_SN_3 AV2_SN_4 AV2_SN_5 AV2_SN_6 AV2_SN_7 AV2_TF_150 AV2_TF_151 AV2_TF_152 AV2_TF_153 AV2_TF_154 AV2_TF_155 AV2_TF_156 AV2_UV_1 AV2_UV_2 AV2_UV_3 AV2_UV_4 AV2_UV_5 AV2_UV_6 AV2_UV_7 AV2_UV_8 AV2_UV_9

# %%
# !cat entropy_header.txt final_snps.recode.mpgl > entropy.mpgl

# %%
cd $ent_dir
# Out:
# /data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy

# %%
# !mkdir shdir

# %%
### select slurm options
account = 'cpu-s5-denovo-0'
partition = 'cpu-core-0'
#account = 'cpu-s1-bionres-0'
#partition = 'cpu-s1-bionres-0'
time = '6-00:00:00' #time limit 4
cpus = 1 #to prevent hammering one node
mem_cpu = 16000
email = 'tfaske@nevada.unr.edu'

#entropy settings
l = 60000
b = 10000
num_k = [2,3,4,5,6,7]
chains = 4

# %%
def write_entropy_sh(account,partition,time,cpus,mem_cpu,email,l,b,num_k,chains):
    for k in num_k:
        for c in range(1,chains+1):
            jobname = 'k%d_c%d' % (k,c)
            seed = random.randint(1000,9999) #default is clock so messes up if submitted same time 
            with open("shdir/run_entropy_%s.sh" % (jobname), "w") as o:
                o.write("""#!/usr/bin/env bash
#SBATCH --account=%s
#SBATCH --partition=%s
#SBATCH --time=%s
#SBATCH --ntasks 1
#SBATCH --cpus-per-task %d
#SBATCH --mem-per-cpu=%d
#SBATCH --job-name ent_%s
#SBATCH --output output_%s.txt
#SBATCH --mail-user=%s\n\n""" % (account,partition,time,cpus,mem_cpu,jobname,jobname,email))
        
                o.write("entropy -i ../entropy.mpgl -o ../entropy_%s.hdf5 -r %d -n 2 -l %d -b %d -t 10 -s 50 -e .01 -k %d -q ../ldak%d.txt -m 1 -w 0"
                        % (jobname,seed,l,b,k,k))

# %%
write_entropy_sh(account,partition,time,cpus,mem_cpu,email,l,b,num_k,chains)

# %%
entShells = !find $ent_dir -name 'run_entropy*.sh'
entShells = entShells.sort()
entShells
# Out:
# ['/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k2_c1.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k2_c2.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k2_c3.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k2_c4.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k3_c1.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k3_c2.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k3_c3.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k3_c4.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k4_c1.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k4_c2.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k4_c3.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k4_c4.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k5_c1.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k5_c2.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k5_c3.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k5_c4.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k6_c1.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k6_c2.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k6_c3.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k6_c4.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k7_c1.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k7_c2.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k7_c3.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_entropy_k7_c4.sh']

# %%
def write_sbatch_entShells(entShells):
         with open("shdir/sbatch_entropy.sh", "w") as o:
            o.write("""#!/usr/bin/env bash \n""")
            for sh in entShells:
                o.write("""sbatch %s\n""" % (sh))

# %%
write_sbatch_entShells(entShells)

# %% [markdown]
# # Run all entropy*sh
#     cd /data/gpfs/home/tfaske/d/milkweed/entropy/shdir
#     source activate entropy
#     bash sbatch_entropy.sh

# %% [markdown]
# # Use estpost to get DIC, q, and gprob

# %%
np.set_printoptions(precision=8) # increases float print option
pd.set_option("precision", 8)

# %%
cd $ent_dir
# Out:
# /data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy

# %%
hdf5_files = !find . -name '*hdf5'
hdf5_files = hdf5_files.sort()
hdf5_files
# Out:
# ['./entropy_k2_c1.hdf5',
#  './entropy_k2_c2.hdf5',
#  './entropy_k2_c3.hdf5',
#  './entropy_k2_c4.hdf5',
#  './entropy_k3_c1.hdf5',
#  './entropy_k3_c2.hdf5',
#  './entropy_k3_c3.hdf5',
#  './entropy_k3_c4.hdf5',
#  './entropy_k4_c1.hdf5',
#  './entropy_k4_c2.hdf5',
#  './entropy_k4_c3.hdf5',
#  './entropy_k4_c4.hdf5',
#  './entropy_k5_c1.hdf5',
#  './entropy_k5_c2.hdf5',
#  './entropy_k5_c3.hdf5',
#  './entropy_k5_c4.hdf5',
#  './entropy_k6_c1.hdf5',
#  './entropy_k6_c2.hdf5',
#  './entropy_k6_c3.hdf5',
#  './entropy_k6_c4.hdf5',
#  './entropy_k7_c1.hdf5',
#  './entropy_k7_c2.hdf5',
#  './entropy_k7_c3.hdf5',
#  './entropy_k7_c4.hdf5']

# %%
estpost = '/data/gpfs/home/tfaske/g/anaconda3/envs/entropy/bin/estpost.entropy'

# %%
#make DIC
for i in range(0,len(hdf5_files)):
    f = hdf5_files[i]
    k = f.split('_')[1] #set this 
    c = f.split('_')[2].split('.hdf5')[0]
    #print(k,c)
    dic = "DIC_%s_%s.txt" % (k,c)
    # !$estpost $f -s 3 -p deviance > $dic
# Out:
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 509 in H5Fopen(): unable to open file
#     major: File accessibilty
#     minor: Unable to open file
#   #001: H5Fint.c line 1661 in H5F_open(): unable to read root group
#     major: File accessibilty
#     minor: Unable to open file
#   #002: H5Groot.c line 239 in H5G_mkroot(): can't check if symbol table message exists
#     major: Symbol table
#     minor: Can't get value
#   #003: H5Omessage.c line 883 in H5O_msg_exists(): unable to protect object header
#     major: Object header
#     minor: Unable to protect metadata
#   #004: H5Oint.c line 1059 in H5O_protect(): unable to load object header
#     major: Object header
#     minor: Unable to protect metadata
#   #005: H5AC.c line 1352 in H5AC_protect(): H5C_protect() failed
#     major: Object cache
#     minor: Unable to protect metadata
#   #006: H5C.c line 2345 in H5C_protect(): can't load entry
#     major: Object cache
#     minor: Unable to load metadata into cache
#   #007: H5C.c line 6685 in H5C_load_entry(): incorrect metadatda checksum after all read attempts
#     major: Object cache
#     minor: Read failed
#   #008: H5Ocache.c line 219 in H5O__cache_get_final_load_size(): can't deserialize object header prefix
#     major: Object header
#     minor: Unable to decode value
#   #009: H5Ocache.c line 1231 in H5O__prefix_deserialize(): bad object header version number
#     major: Object header
#     minor: Wrong version number
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 282 in H5Dopen2(): not a location
#     major: Invalid arguments to routine
#     minor: Inappropriate type
#   #001: H5Gloc.c line 246 in H5G_loc(): invalid object ID
#     major: Invalid arguments to routine
#     minor: Bad value
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 372 in H5Dget_space(): not a dataset
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 921 in H5Sget_simple_extent_ndims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 1013 in H5Sget_simple_extent_dims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Shyper.c line 7053 in H5Sselect_hyperslab(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Dio.c line 177 in H5Dread(): dset_id is not a dataset ID
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 671 in H5Fclose(): not a file ID
#     major: File accessibilty
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 509 in H5Fopen(): unable to open file
#     major: File accessibilty
#     minor: Unable to open file
#   #001: H5Fint.c line 1661 in H5F_open(): unable to read root group
#     major: File accessibilty
#     minor: Unable to open file
#   #002: H5Groot.c line 239 in H5G_mkroot(): can't check if symbol table message exists
#     major: Symbol table
#     minor: Can't get value
#   #003: H5Omessage.c line 883 in H5O_msg_exists(): unable to protect object header
#     major: Object header
#     minor: Unable to protect metadata
#   #004: H5Oint.c line 1059 in H5O_protect(): unable to load object header
#     major: Object header
#     minor: Unable to protect metadata
#   #005: H5AC.c line 1352 in H5AC_protect(): H5C_protect() failed
#     major: Object cache
#     minor: Unable to protect metadata
#   #006: H5C.c line 2345 in H5C_protect(): can't load entry
#     major: Object cache
#     minor: Unable to load metadata into cache
#   #007: H5C.c line 6685 in H5C_load_entry(): incorrect metadatda checksum after all read attempts
#     major: Object cache
#     minor: Read failed
#   #008: H5Ocache.c line 219 in H5O__cache_get_final_load_size(): can't deserialize object header prefix
#     major: Object header
#     minor: Unable to decode value
#   #009: H5Ocache.c line 1231 in H5O__prefix_deserialize(): bad object header version number
#     major: Object header
#     minor: Wrong version number
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 282 in H5Dopen2(): not a location
#     major: Invalid arguments to routine
#     minor: Inappropriate type
#   #001: H5Gloc.c line 246 in H5G_loc(): invalid object ID
#     major: Invalid arguments to routine
#     minor: Bad value
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 372 in H5Dget_space(): not a dataset
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 921 in H5Sget_simple_extent_ndims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 1013 in H5Sget_simple_extent_dims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Shyper.c line 7053 in H5Sselect_hyperslab(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Dio.c line 177 in H5Dread(): dset_id is not a dataset ID
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 671 in H5Fclose(): not a file ID
#     major: File accessibilty
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 509 in H5Fopen(): unable to open file
#     major: File accessibilty
#     minor: Unable to open file
#   #001: H5Fint.c line 1661 in H5F_open(): unable to read root group
#     major: File accessibilty
#     minor: Unable to open file
#   #002: H5Groot.c line 239 in H5G_mkroot(): can't check if symbol table message exists
#     major: Symbol table
#     minor: Can't get value
#   #003: H5Omessage.c line 883 in H5O_msg_exists(): unable to protect object header
#     major: Object header
#     minor: Unable to protect metadata
#   #004: H5Oint.c line 1059 in H5O_protect(): unable to load object header
#     major: Object header
#     minor: Unable to protect metadata
#   #005: H5AC.c line 1352 in H5AC_protect(): H5C_protect() failed
#     major: Object cache
#     minor: Unable to protect metadata
#   #006: H5C.c line 2345 in H5C_protect(): can't load entry
#     major: Object cache
#     minor: Unable to load metadata into cache
#   #007: H5C.c line 6685 in H5C_load_entry(): incorrect metadatda checksum after all read attempts
#     major: Object cache
#     minor: Read failed
#   #008: H5Ocache.c line 219 in H5O__cache_get_final_load_size(): can't deserialize object header prefix
#     major: Object header
#     minor: Unable to decode value
#   #009: H5Ocache.c line 1231 in H5O__prefix_deserialize(): bad object header version number
#     major: Object header
#     minor: Wrong version number
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 282 in H5Dopen2(): not a location
#     major: Invalid arguments to routine
#     minor: Inappropriate type
#   #001: H5Gloc.c line 246 in H5G_loc(): invalid object ID
#     major: Invalid arguments to routine
#     minor: Bad value
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 372 in H5Dget_space(): not a dataset
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 921 in H5Sget_simple_extent_ndims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 1013 in H5Sget_simple_extent_dims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Shyper.c line 7053 in H5Sselect_hyperslab(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Dio.c line 177 in H5Dread(): dset_id is not a dataset ID
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 671 in H5Fclose(): not a file ID
#     major: File accessibilty
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 509 in H5Fopen(): unable to open file
#     major: File accessibilty
#     minor: Unable to open file
#   #001: H5Fint.c line 1661 in H5F_open(): unable to read root group
#     major: File accessibilty
#     minor: Unable to open file
#   #002: H5Groot.c line 239 in H5G_mkroot(): can't check if symbol table message exists
#     major: Symbol table
#     minor: Can't get value
#   #003: H5Omessage.c line 883 in H5O_msg_exists(): unable to protect object header
#     major: Object header
#     minor: Unable to protect metadata
#   #004: H5Oint.c line 1059 in H5O_protect(): unable to load object header
#     major: Object header
#     minor: Unable to protect metadata
#   #005: H5AC.c line 1352 in H5AC_protect(): H5C_protect() failed
#     major: Object cache
#     minor: Unable to protect metadata
#   #006: H5C.c line 2345 in H5C_protect(): can't load entry
#     major: Object cache
#     minor: Unable to load metadata into cache
#   #007: H5C.c line 6685 in H5C_load_entry(): incorrect metadatda checksum after all read attempts
#     major: Object cache
#     minor: Read failed
#   #008: H5Ocache.c line 219 in H5O__cache_get_final_load_size(): can't deserialize object header prefix
#     major: Object header
#     minor: Unable to decode value
#   #009: H5Ocache.c line 1231 in H5O__prefix_deserialize(): bad object header version number
#     major: Object header
#     minor: Wrong version number
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 282 in H5Dopen2(): not a location
#     major: Invalid arguments to routine
#     minor: Inappropriate type
#   #001: H5Gloc.c line 246 in H5G_loc(): invalid object ID
#     major: Invalid arguments to routine
#     minor: Bad value
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 372 in H5Dget_space(): not a dataset
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 921 in H5Sget_simple_extent_ndims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 1013 in H5Sget_simple_extent_dims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Shyper.c line 7053 in H5Sselect_hyperslab(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Dio.c line 177 in H5Dread(): dset_id is not a dataset ID
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 671 in H5Fclose(): not a file ID
#     major: File accessibilty
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 509 in H5Fopen(): unable to open file
#     major: File accessibilty
#     minor: Unable to open file
#   #001: H5Fint.c line 1661 in H5F_open(): unable to read root group
#     major: File accessibilty
#     minor: Unable to open file
#   #002: H5Groot.c line 239 in H5G_mkroot(): can't check if symbol table message exists
#     major: Symbol table
#     minor: Can't get value
#   #003: H5Omessage.c line 883 in H5O_msg_exists(): unable to protect object header
#     major: Object header
#     minor: Unable to protect metadata
#   #004: H5Oint.c line 1059 in H5O_protect(): unable to load object header
#     major: Object header
#     minor: Unable to protect metadata
#   #005: H5AC.c line 1352 in H5AC_protect(): H5C_protect() failed
#     major: Object cache
#     minor: Unable to protect metadata
#   #006: H5C.c line 2345 in H5C_protect(): can't load entry
#     major: Object cache
#     minor: Unable to load metadata into cache
#   #007: H5C.c line 6685 in H5C_load_entry(): incorrect metadatda checksum after all read attempts
#     major: Object cache
#     minor: Read failed
#   #008: H5Ocache.c line 219 in H5O__cache_get_final_load_size(): can't deserialize object header prefix
#     major: Object header
#     minor: Unable to decode value
#   #009: H5Ocache.c line 1231 in H5O__prefix_deserialize(): bad object header version number
#     major: Object header
#     minor: Wrong version number
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 282 in H5Dopen2(): not a location
#     major: Invalid arguments to routine
#     minor: Inappropriate type
#   #001: H5Gloc.c line 246 in H5G_loc(): invalid object ID
#     major: Invalid arguments to routine
#     minor: Bad value
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 372 in H5Dget_space(): not a dataset
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 921 in H5Sget_simple_extent_ndims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 1013 in H5Sget_simple_extent_dims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Shyper.c line 7053 in H5Sselect_hyperslab(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Dio.c line 177 in H5Dread(): dset_id is not a dataset ID
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 671 in H5Fclose(): not a file ID
#     major: File accessibilty
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 509 in H5Fopen(): unable to open file
#     major: File accessibilty
#     minor: Unable to open file
#   #001: H5Fint.c line 1661 in H5F_open(): unable to read root group
#     major: File accessibilty
#     minor: Unable to open file
#   #002: H5Groot.c line 239 in H5G_mkroot(): can't check if symbol table message exists
#     major: Symbol table
#     minor: Can't get value
#   #003: H5Omessage.c line 883 in H5O_msg_exists(): unable to protect object header
#     major: Object header
#     minor: Unable to protect metadata
#   #004: H5Oint.c line 1059 in H5O_protect(): unable to load object header
#     major: Object header
#     minor: Unable to protect metadata
#   #005: H5AC.c line 1352 in H5AC_protect(): H5C_protect() failed
#     major: Object cache
#     minor: Unable to protect metadata
#   #006: H5C.c line 2345 in H5C_protect(): can't load entry
#     major: Object cache
#     minor: Unable to load metadata into cache
#   #007: H5C.c line 6685 in H5C_load_entry(): incorrect metadatda checksum after all read attempts
#     major: Object cache
#     minor: Read failed
#   #008: H5Ocache.c line 219 in H5O__cache_get_final_load_size(): can't deserialize object header prefix
#     major: Object header
#     minor: Unable to decode value
#   #009: H5Ocache.c line 1231 in H5O__prefix_deserialize(): bad object header version number
#     major: Object header
#     minor: Wrong version number
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 282 in H5Dopen2(): not a location
#     major: Invalid arguments to routine
#     minor: Inappropriate type
#   #001: H5Gloc.c line 246 in H5G_loc(): invalid object ID
#     major: Invalid arguments to routine
#     minor: Bad value
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 372 in H5Dget_space(): not a dataset
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 921 in H5Sget_simple_extent_ndims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 1013 in H5Sget_simple_extent_dims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Shyper.c line 7053 in H5Sselect_hyperslab(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Dio.c line 177 in H5Dread(): dset_id is not a dataset ID
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 671 in H5Fclose(): not a file ID
#     major: File accessibilty
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 509 in H5Fopen(): unable to open file
#     major: File accessibilty
#     minor: Unable to open file
#   #001: H5Fint.c line 1661 in H5F_open(): unable to read root group
#     major: File accessibilty
#     minor: Unable to open file
#   #002: H5Groot.c line 239 in H5G_mkroot(): can't check if symbol table message exists
#     major: Symbol table
#     minor: Can't get value
#   #003: H5Omessage.c line 883 in H5O_msg_exists(): unable to protect object header
#     major: Object header
#     minor: Unable to protect metadata
#   #004: H5Oint.c line 1059 in H5O_protect(): unable to load object header
#     major: Object header
#     minor: Unable to protect metadata
#   #005: H5AC.c line 1352 in H5AC_protect(): H5C_protect() failed
#     major: Object cache
#     minor: Unable to protect metadata
#   #006: H5C.c line 2345 in H5C_protect(): can't load entry
#     major: Object cache
#     minor: Unable to load metadata into cache
#   #007: H5C.c line 6685 in H5C_load_entry(): incorrect metadatda checksum after all read attempts
#     major: Object cache
#     minor: Read failed
#   #008: H5Ocache.c line 219 in H5O__cache_get_final_load_size(): can't deserialize object header prefix
#     major: Object header
#     minor: Unable to decode value
#   #009: H5Ocache.c line 1231 in H5O__prefix_deserialize(): bad object header version number
#     major: Object header
#     minor: Wrong version number
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 282 in H5Dopen2(): not a location
#     major: Invalid arguments to routine
#     minor: Inappropriate type
#   #001: H5Gloc.c line 246 in H5G_loc(): invalid object ID
#     major: Invalid arguments to routine
#     minor: Bad value
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 372 in H5Dget_space(): not a dataset
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 921 in H5Sget_simple_extent_ndims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 1013 in H5Sget_simple_extent_dims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Shyper.c line 7053 in H5Sselect_hyperslab(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Dio.c line 177 in H5Dread(): dset_id is not a dataset ID
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 671 in H5Fclose(): not a file ID
#     major: File accessibilty
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 509 in H5Fopen(): unable to open file
#     major: File accessibilty
#     minor: Unable to open file
#   #001: H5Fint.c line 1661 in H5F_open(): unable to read root group
#     major: File accessibilty
#     minor: Unable to open file
#   #002: H5Groot.c line 239 in H5G_mkroot(): can't check if symbol table message exists
#     major: Symbol table
#     minor: Can't get value
#   #003: H5Omessage.c line 883 in H5O_msg_exists(): unable to protect object header
#     major: Object header
#     minor: Unable to protect metadata
#   #004: H5Oint.c line 1059 in H5O_protect(): unable to load object header
#     major: Object header
#     minor: Unable to protect metadata
#   #005: H5AC.c line 1352 in H5AC_protect(): H5C_protect() failed
#     major: Object cache
#     minor: Unable to protect metadata
#   #006: H5C.c line 2345 in H5C_protect(): can't load entry
#     major: Object cache
#     minor: Unable to load metadata into cache
#   #007: H5C.c line 6685 in H5C_load_entry(): incorrect metadatda checksum after all read attempts
#     major: Object cache
#     minor: Read failed
#   #008: H5Ocache.c line 219 in H5O__cache_get_final_load_size(): can't deserialize object header prefix
#     major: Object header
#     minor: Unable to decode value
#   #009: H5Ocache.c line 1231 in H5O__prefix_deserialize(): bad object header version number
#     major: Object header
#     minor: Wrong version number
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 282 in H5Dopen2(): not a location
#     major: Invalid arguments to routine
#     minor: Inappropriate type
#   #001: H5Gloc.c line 246 in H5G_loc(): invalid object ID
#     major: Invalid arguments to routine
#     minor: Bad value
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 372 in H5Dget_space(): not a dataset
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 921 in H5Sget_simple_extent_ndims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 1013 in H5Sget_simple_extent_dims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Shyper.c line 7053 in H5Sselect_hyperslab(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Dio.c line 177 in H5Dread(): dset_id is not a dataset ID
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 671 in H5Fclose(): not a file ID
#     major: File accessibilty
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 509 in H5Fopen(): unable to open file
#     major: File accessibilty
#     minor: Unable to open file
#   #001: H5Fint.c line 1661 in H5F_open(): unable to read root group
#     major: File accessibilty
#     minor: Unable to open file
#   #002: H5Groot.c line 239 in H5G_mkroot(): can't check if symbol table message exists
#     major: Symbol table
#     minor: Can't get value
#   #003: H5Omessage.c line 883 in H5O_msg_exists(): unable to protect object header
#     major: Object header
#     minor: Unable to protect metadata
#   #004: H5Oint.c line 1059 in H5O_protect(): unable to load object header
#     major: Object header
#     minor: Unable to protect metadata
#   #005: H5AC.c line 1352 in H5AC_protect(): H5C_protect() failed
#     major: Object cache
#     minor: Unable to protect metadata
#   #006: H5C.c line 2345 in H5C_protect(): can't load entry
#     major: Object cache
#     minor: Unable to load metadata into cache
#   #007: H5C.c line 6685 in H5C_load_entry(): incorrect metadatda checksum after all read attempts
#     major: Object cache
#     minor: Read failed
#   #008: H5Ocache.c line 219 in H5O__cache_get_final_load_size(): can't deserialize object header prefix
#     major: Object header
#     minor: Unable to decode value
#   #009: H5Ocache.c line 1231 in H5O__prefix_deserialize(): bad object header version number
#     major: Object header
#     minor: Wrong version number
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 282 in H5Dopen2(): not a location
#     major: Invalid arguments to routine
#     minor: Inappropriate type
#   #001: H5Gloc.c line 246 in H5G_loc(): invalid object ID
#     major: Invalid arguments to routine
#     minor: Bad value
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 372 in H5Dget_space(): not a dataset
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 921 in H5Sget_simple_extent_ndims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 1013 in H5Sget_simple_extent_dims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Shyper.c line 7053 in H5Sselect_hyperslab(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Dio.c line 177 in H5Dread(): dset_id is not a dataset ID
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 671 in H5Fclose(): not a file ID
#     major: File accessibilty
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 509 in H5Fopen(): unable to open file
#     major: File accessibilty
#     minor: Unable to open file
#   #001: H5Fint.c line 1661 in H5F_open(): unable to read root group
#     major: File accessibilty
#     minor: Unable to open file
#   #002: H5Groot.c line 239 in H5G_mkroot(): can't check if symbol table message exists
#     major: Symbol table
#     minor: Can't get value
#   #003: H5Omessage.c line 883 in H5O_msg_exists(): unable to protect object header
#     major: Object header
#     minor: Unable to protect metadata
#   #004: H5Oint.c line 1059 in H5O_protect(): unable to load object header
#     major: Object header
#     minor: Unable to protect metadata
#   #005: H5AC.c line 1352 in H5AC_protect(): H5C_protect() failed
#     major: Object cache
#     minor: Unable to protect metadata
#   #006: H5C.c line 2345 in H5C_protect(): can't load entry
#     major: Object cache
#     minor: Unable to load metadata into cache
#   #007: H5C.c line 6685 in H5C_load_entry(): incorrect metadatda checksum after all read attempts
#     major: Object cache
#     minor: Read failed
#   #008: H5Ocache.c line 219 in H5O__cache_get_final_load_size(): can't deserialize object header prefix
#     major: Object header
#     minor: Unable to decode value
#   #009: H5Ocache.c line 1231 in H5O__prefix_deserialize(): bad object header version number
#     major: Object header
#     minor: Wrong version number
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 282 in H5Dopen2(): not a location
#     major: Invalid arguments to routine
#     minor: Inappropriate type
#   #001: H5Gloc.c line 246 in H5G_loc(): invalid object ID
#     major: Invalid arguments to routine
#     minor: Bad value
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 372 in H5Dget_space(): not a dataset
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 921 in H5Sget_simple_extent_ndims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 1013 in H5Sget_simple_extent_dims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Shyper.c line 7053 in H5Sselect_hyperslab(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Dio.c line 177 in H5Dread(): dset_id is not a dataset ID
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 671 in H5Fclose(): not a file ID
#     major: File accessibilty
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 509 in H5Fopen(): unable to open file
#     major: File accessibilty
#     minor: Unable to open file
#   #001: H5Fint.c line 1661 in H5F_open(): unable to read root group
#     major: File accessibilty
#     minor: Unable to open file
#   #002: H5Groot.c line 239 in H5G_mkroot(): can't check if symbol table message exists
#     major: Symbol table
#     minor: Can't get value
#   #003: H5Omessage.c line 883 in H5O_msg_exists(): unable to protect object header
#     major: Object header
#     minor: Unable to protect metadata
#   #004: H5Oint.c line 1059 in H5O_protect(): unable to load object header
#     major: Object header
#     minor: Unable to protect metadata
#   #005: H5AC.c line 1352 in H5AC_protect(): H5C_protect() failed
#     major: Object cache
#     minor: Unable to protect metadata
#   #006: H5C.c line 2345 in H5C_protect(): can't load entry
#     major: Object cache
#     minor: Unable to load metadata into cache
#   #007: H5C.c line 6685 in H5C_load_entry(): incorrect metadatda checksum after all read attempts
#     major: Object cache
#     minor: Read failed
#   #008: H5Ocache.c line 219 in H5O__cache_get_final_load_size(): can't deserialize object header prefix
#     major: Object header
#     minor: Unable to decode value
#   #009: H5Ocache.c line 1231 in H5O__prefix_deserialize(): bad object header version number
#     major: Object header
#     minor: Wrong version number
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 282 in H5Dopen2(): not a location
#     major: Invalid arguments to routine
#     minor: Inappropriate type
#   #001: H5Gloc.c line 246 in H5G_loc(): invalid object ID
#     major: Invalid arguments to routine
#     minor: Bad value
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 372 in H5Dget_space(): not a dataset
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 921 in H5Sget_simple_extent_ndims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 1013 in H5Sget_simple_extent_dims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Shyper.c line 7053 in H5Sselect_hyperslab(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Dio.c line 177 in H5Dread(): dset_id is not a dataset ID
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 671 in H5Fclose(): not a file ID
#     major: File accessibilty
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 509 in H5Fopen(): unable to open file
#     major: File accessibilty
#     minor: Unable to open file
#   #001: H5Fint.c line 1661 in H5F_open(): unable to read root group
#     major: File accessibilty
#     minor: Unable to open file
#   #002: H5Groot.c line 239 in H5G_mkroot(): can't check if symbol table message exists
#     major: Symbol table
#     minor: Can't get value
#   #003: H5Omessage.c line 883 in H5O_msg_exists(): unable to protect object header
#     major: Object header
#     minor: Unable to protect metadata
#   #004: H5Oint.c line 1059 in H5O_protect(): unable to load object header
#     major: Object header
#     minor: Unable to protect metadata
#   #005: H5AC.c line 1352 in H5AC_protect(): H5C_protect() failed
#     major: Object cache
#     minor: Unable to protect metadata
#   #006: H5C.c line 2345 in H5C_protect(): can't load entry
#     major: Object cache
#     minor: Unable to load metadata into cache
#   #007: H5C.c line 6685 in H5C_load_entry(): incorrect metadatda checksum after all read attempts
#     major: Object cache
#     minor: Read failed
#   #008: H5Ocache.c line 219 in H5O__cache_get_final_load_size(): can't deserialize object header prefix
#     major: Object header
#     minor: Unable to decode value
#   #009: H5Ocache.c line 1231 in H5O__prefix_deserialize(): bad object header version number
#     major: Object header
#     minor: Wrong version number
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 282 in H5Dopen2(): not a location
#     major: Invalid arguments to routine
#     minor: Inappropriate type
#   #001: H5Gloc.c line 246 in H5G_loc(): invalid object ID
#     major: Invalid arguments to routine
#     minor: Bad value
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5D.c line 372 in H5Dget_space(): not a dataset
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 921 in H5Sget_simple_extent_ndims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5S.c line 1013 in H5Sget_simple_extent_dims(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Shyper.c line 7053 in H5Sselect_hyperslab(): not a dataspace
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5Dio.c line 177 in H5Dread(): dset_id is not a dataset ID
#     major: Invalid arguments to routine
#     minor: Inappropriate type
# HDF5-DIAG: Error detected in HDF5 (1.10.5) thread 46912498158592:
#   #000: H5F.c line 671 in H5Fclose(): not a file ID
#     major: File accessibilty
#     minor: Inappropriate type

# %%
dic_files = !find . -name 'DIC*'
dic_files
# Out:
# ['./DIC_k2_c4.txt',
#  './DIC_k7_c2.txt',
#  './DIC_k2_c1.txt',
#  './DIC_k6_c1.txt',
#  './DIC_k3_c2.txt',
#  './DIC_k4_c4.txt',
#  './DIC_k4_c2.txt',
#  './DIC_k7_c1.txt',
#  './DIC_k7_c4.txt',
#  './DIC_k5_c2.txt',
#  './DIC_k6_c2.txt',
#  './DIC_k4_c3.txt',
#  './DIC_k7_c3.txt',
#  './DIC_k3_c1.txt',
#  './DIC_k2_c2.txt',
#  './DIC_k5_c4.txt',
#  './DIC_k6_c3.txt',
#  './DIC_k4_c1.txt',
#  './DIC_k2_c3.txt',
#  './DIC_k6_c4.txt',
#  './DIC_k3_c4.txt',
#  './DIC_k5_c1.txt',
#  './DIC_k3_c3.txt',
#  './DIC_k5_c3.txt']

# %%
for d in dic_files:
    # !cat $d
    print('\n')
# Out:
# file = ./entropy_k2_c4.hdf5
# parameter dimensions for deviance: samples = 5000, chains = 1
# Model deviance: 8471479.26
# Effective number of parameters: 7698594.18
# Model DIC: 16170073.44
#
#
# file = ./entropy_k7_c2.hdf5
# parameter dimensions for deviance: samples = 9, chains = 1
# Model deviance: 0.00
# Effective number of parameters: 0.00
# Model DIC: 0.00
#
#
# file = ./entropy_k2_c1.hdf5
# parameter dimensions for deviance: samples = 5000, chains = 1
# Model deviance: 8471646.19
# Effective number of parameters: 7485784.25
# Model DIC: 15957430.44
#
#
# file = ./entropy_k6_c1.hdf5
# parameter dimensions for deviance: samples = 9, chains = 1
# Model deviance: 0.00
# Effective number of parameters: 0.00
# Model DIC: 0.00
#
#
# file = ./entropy_k3_c2.hdf5
# parameter dimensions for deviance: samples = 5000, chains = 1
# Model deviance: 8227776.34
# Effective number of parameters: 8458046.06
# Model DIC: 16685822.40
#
#
# file = ./entropy_k4_c4.hdf5
# parameter dimensions for deviance: samples = 5000, chains = 1
# Model deviance: 8158802.11
# Effective number of parameters: 8421588.55
# Model DIC: 16580390.66
#
#
# file = ./entropy_k4_c2.hdf5
# parameter dimensions for deviance: samples = 5000, chains = 1
# Model deviance: 8158833.76
# Effective number of parameters: 8346018.32
# Model DIC: 16504852.07
#
#
# file = ./entropy_k7_c1.hdf5
# parameter dimensions for deviance: samples = 9, chains = 1
# Model deviance: 0.00
# Effective number of parameters: 0.00
# Model DIC: 0.00
#
#
# file = ./entropy_k7_c4.hdf5
# parameter dimensions for deviance: samples = 9, chains = 1
# Model deviance: 0.00
# Effective number of parameters: 0.00
# Model DIC: 0.00
#
#
# file = ./entropy_k5_c2.hdf5
# parameter dimensions for deviance: samples = 9, chains = 1
# Model deviance: 0.00
# Effective number of parameters: 0.00
# Model DIC: 0.00
#
#
# file = ./entropy_k6_c2.hdf5
# parameter dimensions for deviance: samples = 9, chains = 1
# Model deviance: 0.00
# Effective number of parameters: 0.00
# Model DIC: 0.00
#
#
# file = ./entropy_k4_c3.hdf5
# parameter dimensions for deviance: samples = 5000, chains = 1
# Model deviance: 8157628.37
# Effective number of parameters: 8368097.50
# Model DIC: 16525725.88
#
#
# file = ./entropy_k7_c3.hdf5
# parameter dimensions for deviance: samples = 9, chains = 1
# Model deviance: 0.00
# Effective number of parameters: 0.00
# Model DIC: 0.00
#
#
# file = ./entropy_k3_c1.hdf5
# parameter dimensions for deviance: samples = 5000, chains = 1
# Model deviance: 8227478.16
# Effective number of parameters: 8827726.34
# Model DIC: 17055204.50
#
#
# file = ./entropy_k2_c2.hdf5
# parameter dimensions for deviance: samples = 5000, chains = 1
# Model deviance: 8471379.67
# Effective number of parameters: 7192820.18
# Model DIC: 15664199.85
#
#
# file = ./entropy_k5_c4.hdf5
# parameter dimensions for deviance: samples = 9, chains = 1
# Model deviance: 0.00
# Effective number of parameters: 0.00
# Model DIC: 0.00
#
#
# file = ./entropy_k6_c3.hdf5
# parameter dimensions for deviance: samples = 9, chains = 1
# Model deviance: 0.00
# Effective number of parameters: 0.00
# Model DIC: 0.00
#
#
# file = ./entropy_k4_c1.hdf5
# parameter dimensions for deviance: samples = 5000, chains = 1
# Model deviance: 8158628.38
# Effective number of parameters: 8705644.68
# Model DIC: 16864273.06
#
#
# file = ./entropy_k2_c3.hdf5
# parameter dimensions for deviance: samples = 5000, chains = 1
# Model deviance: 8471348.86
# Effective number of parameters: 6944114.03
# Model DIC: 15415462.89
#
#
# file = ./entropy_k6_c4.hdf5
# parameter dimensions for deviance: samples = 9, chains = 1
# Model deviance: 0.00
# Effective number of parameters: 0.00
# Model DIC: 0.00
#
#
# file = ./entropy_k3_c4.hdf5
# parameter dimensions for deviance: samples = 5000, chains = 1
# Model deviance: 8227519.73
# Effective number of parameters: 8711851.73
# Model DIC: 16939371.46
#
#
# file = ./entropy_k5_c1.hdf5
# parameter dimensions for deviance: samples = 9, chains = 1
# Model deviance: 0.00
# Effective number of parameters: 0.00
# Model DIC: 0.00
#
#
# file = ./entropy_k3_c3.hdf5
# parameter dimensions for deviance: samples = 5000, chains = 1
# Model deviance: 8227555.87
# Effective number of parameters: 8285856.53
# Model DIC: 16513412.40
#
#
# file = ./entropy_k5_c3.hdf5
# parameter dimensions for deviance: samples = 9, chains = 1
# Model deviance: 0.00
# Effective number of parameters: 0.00
# Model DIC: 0.00

# %%
dic_list = []
for d in dic_files:
    k = d.split('_k')[1].split('_')[0] #set this 
    c = d.split('_c')[1].split('.txt')[0]
    #print(k,c)
    
    dic = !grep 'DIC' $d
    dic = float(re.search('(\d+.\d+)',str(dic)).group(0))
    #print(dic)
    
    dic_list.append([k,dic,c])
dic_df = pd.DataFrame(dic_list,columns=['k','DIC','chain'])
dic_df.head()
# Out:
#    k          DIC chain
# 0  2  16170073.44     4
# 1  7         0.00     2
# 2  2  15957430.44     1
# 3  6         0.00     1
# 4  3  16685822.40     2

# %%
dic_df.to_csv('dic_list.csv')

# %%
dic_sum = dic_df.groupby('k').describe().DIC

# %%
dic_sum.sort_values('mean')
# Out:
#    count           mean              std          min            25%  \
# k
# 5    4.0         0.0000       0.00000000         0.00         0.0000
# 6    4.0         0.0000       0.00000000         0.00         0.0000
# 7    4.0         0.0000       0.00000000         0.00         0.0000
# 2    4.0  15801791.6550  330674.22237435  15415462.89  15602015.6100
# 4    4.0  16618810.4175  166712.54973353  16504852.07  16520507.4275
# 3    4.0  16798452.6900  244753.71350629  16513412.40  16642719.9000
#
#             50%          75%          max
# k
# 5         0.000         0.00         0.00
# 6         0.000         0.00         0.00
# 7         0.000         0.00         0.00
# 2  15810815.145  16010591.19  16170073.44
# 4  16553058.270  16651361.26  16864273.06
# 3  16812596.930  16968329.72  17055204.50

# %%
dic_sum.to_csv('dic_sum.csv')

# %% [markdown]
# ### Get gprob and q for each k, and mcmc metrics

# %%
# ancestry coeffecients 
# !$estpost *k2*.hdf5 -p q -s 0 -o q2.txt

# !$estpost *k3*.hdf5 -p q -s 0 -o q3.txt

# !$estpost *k4*.hdf5 -p q -s 0 -o q4.txt

#!$estpost *k5*.hdf5 -p q -s 0 -o q5.txt

#!$estpost *k6*.hdf5 -p q -s 0 -o q6.txt

#!$estpost *k7*.hdf5 -p q -s 0 -o q7.txt
# Out:
# file = entropy_k2_c1.hdf5
# file = entropy_k2_c2.hdf5
# file = entropy_k2_c3.hdf5
# file = entropy_k2_c4.hdf5
# parameter dimensions for q: ind = 397, populations = 2, samples = 5000, chains = 4
# file = entropy_k3_c1.hdf5
# file = entropy_k3_c2.hdf5
# file = entropy_k3_c3.hdf5
# file = entropy_k3_c4.hdf5
# parameter dimensions for q: ind = 397, populations = 3, samples = 5000, chains = 4
# file = entropy_k4_c1.hdf5
# file = entropy_k4_c2.hdf5
# file = entropy_k4_c3.hdf5
# file = entropy_k4_c4.hdf5
# parameter dimensions for q: ind = 397, populations = 4, samples = 5000, chains = 4

# %%
#MCMC diagnostics
# !$estpost *k2*.hdf5 -p q -s 4 -o MCMC_k2.txt

# !$estpost *k3*.hdf5 -p q -s 4 -o MCMC_k3.txt

# !$estpost *k4*.hdf5 -p q -s 4 -o MCMC_k4.txt

#!$estpost *k5*.hdf5 -p q -s 4 -o MCMC_k5.txt

#!$estpost *k6*.hdf5 -p q -s 4 -o MCMC_k6.txt

#!$estpost *k7*.hdf5 -p q -s 4 -o MCMC_k7.txt
# Out:
# file = entropy_k2_c1.hdf5
# file = entropy_k2_c2.hdf5
# file = entropy_k2_c3.hdf5
# file = entropy_k2_c4.hdf5
# parameter dimensions for q: ind = 397, populations = 2, samples = 5000, chains = 4
# file = entropy_k3_c1.hdf5
# file = entropy_k3_c2.hdf5
# file = entropy_k3_c3.hdf5
# file = entropy_k3_c4.hdf5
# parameter dimensions for q: ind = 397, populations = 3, samples = 5000, chains = 4
# file = entropy_k4_c1.hdf5
# file = entropy_k4_c2.hdf5
# file = entropy_k4_c3.hdf5
# file = entropy_k4_c4.hdf5
# parameter dimensions for q: ind = 397, populations = 4, samples = 5000, chains = 4

# %% [markdown]
# ### make slurm script to make gprob file
#
#     use all k and chains to make gprob

# %%
cd $ent_dir
# Out:
# /data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy

# %%
### select slurm options
account = 'cpu-s5-denovo-0'
partition = 'cpu-core-0'
time = '1-00:00:00' #time limit 4
cpus = 2 #to prevent hammering one node
mem_cpu = 6000
email = 'tfaske@nevada.unr.edu'

### select k 
num_k = [2,3,4,6,7]

# %%
def write_gprob_k_sh(account,partition,time,cpus,mem_cpu,email,estpost,num_k):
    for k in num_k:
        with open("shdir/run_gprob_k%d.sh" % (k), "w") as o:
            o.write("""#!/usr/bin/env bash
#SBATCH --account=%s
#SBATCH --partition=%s
#SBATCH --time=%s
#SBATCH --ntasks 1
#SBATCH --cpus-per-task %d
#SBATCH --mem-per-cpu=%d
#SBATCH --job-name gprob_k%d
#SBATCH --output output_gprob_k%d.txt
#SBATCH --mail-type=END
#SBATCH --mail-user=%s\n\n""" % (account,partition,time,cpus,mem_cpu,k,k,email))
        
            o.write("%s ../*k%d*.hdf5 -p gprob -s 0 -o ../gprob%d.txt" % (estpost,k,k))

# %%
write_gprob_k_sh(account,partition,time,cpus,mem_cpu,email,estpost,num_k)

# %%
gprobShells = !find $ent_dir -name 'run_gprob*.sh'
gprobShells = gprobShells.sort()
gprobShells
# Out:
# ['/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_gprob_k2.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_gprob_k3.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_gprob_k4.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_gprob_k6.sh',
#  '/data/gpfs/assoc/denovo/tfaske/sagebrush/SNPcall/ATAV2/entropy/shdir/run_gprob_k7.sh']

# %%
def write_sbatch_gprobShells(gprobShells):
    with open("shdir/sbatch_gprob.sh", "w") as o:
        o.write("""#!/usr/bin/env bash \n""")
        for sh in gprobShells:
            o.write("""sbatch %s\n""" % (sh))

# %%
write_sbatch_gprobShells(gprobShells)

# %% [markdown]
# ### gprob all

# %%
hdf5_files = []
for k in num_k:
    f = '../entropy_k' + str(k) + '_c*hdf5'
    hdf5_files.append(f)
hdf5_files
# Out:
# ['../entropy_k2_c*hdf5',
#  '../entropy_k3_c*hdf5',
#  '../entropy_k4_c*hdf5',
#  '../entropy_k6_c*hdf5',
#  '../entropy_k7_c*hdf5']

# %%
gprob_cmd = estpost + ' ' + ' '.join(hdf5_files) + ' -p gprob -s 0 -o ../gprobAll.txt'
gprob_cmd
# Out:
# '/data/gpfs/home/tfaske/g/anaconda3/envs/entropy/bin/estpost.entropy ../entropy_k2_c*hdf5 ../entropy_k3_c*hdf5 ../entropy_k4_c*hdf5 ../entropy_k6_c*hdf5 ../entropy_k7_c*hdf5 -p gprob -s 0 -o ../gprobAll.txt'

# %%
### select slurm options
account = 'cpu-s5-denovo-0'
partition = 'cpu-core-0'
time = '1-00:00:00' #time limit 4
cpus = 1 #to prevent hammering one node
mem_cpu = 100000
email = 'tfaske@nevada.unr.edu'

# %%
def write_gprob_all_sh(account,partition,time,cpus,mem_cpu,email,estpost,gprob_cmd):
        with open("shdir/run_gprobAll.sh", "w") as o:
            o.write("""#!/usr/bin/env bash
#SBATCH --account=%s
#SBATCH --partition=%s
#SBATCH --time=%s
#SBATCH --ntasks 1
#SBATCH --cpus-per-task %d
#SBATCH --mem-per-cpu=%d
#SBATCH --job-name gprobAll
#SBATCH --output output_gprobAll.txt
#SBATCH --mail-type=END
#SBATCH --mail-user=%s

# %s""" % (account,partition,time,cpus,mem_cpu,email,gprob_cmd))

# %%
write_gprob_all_sh(account,partition,time,cpus,mem_cpu,email,estpost,gprob_cmd)

# %% [markdown]
# ## Run gprob sh
#     cd /data/gpfs/home/tfaske/d/sagebrush/SNPcall/AT2/entropy
#     source activate entropy
#     sbatch run_gprob.sh

# %%
#gprobs
#!$estpost *k2*.hdf5 -p gprob -s 0 -o gprob2.txt

#!$estpost *k3*.hdf5 -p gprob -s 0 -o gprob3.txt

#!$estpost *k4*.hdf5 -p gprob -s 0 -o gprob4.txt

#!$estpost *k5*.hdf5 -p gprob -s 0 -o gprob5.txt
